# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
bandcamp_url = "https://horsevision.bandcamp.com/album/another-life"
bandcamp_track_url = "https://horsevision.bandcamp.com/track/how-are-we"

# %%
def extract_jsonld_from_bandcamp(bandcamp_url: str)-> json:
    """
    Extract JSON-LD structured data from a Bandcamp page.
    
    Args:
        url: Bandcamp track or album URL
        
    Returns:
        Parsed JSON data as a Python dictionary, or None if not found
    """
    try:
        #1. Fetch the page
        response = requests.get(bandcamp_url, timeout=10)
        response.raise_for_status()  # Raise error for bad status codes
        
        # 2. Parse HTML with BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        
        #3. Find the script tag with JSON-LD
        # Look for: <script type="application/ld+json">
        jsonld_script = soup.find('script', {'type': 'application/ld+json'})
        
        if not jsonld_script:
            print("No JSON-LD script tag found")
            return None
        
        #4. Extract the text content from the script tag
        jsonld_text = jsonld_script.string
        
        #5. Parse the JSON string into a Python dictionary
        jsonld_data = json.loads(jsonld_text)
        
        return jsonld_data
        
    except requests.RequestException as e:
        print(f"Error fetching URL: {e}")
        return None
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error: {e}")
        return None

# %%
jsonld_data = extract_jsonld_from_bandcamp(bandcamp_track_url)
print(jsonld_data)
# Out:
# {'@type': 'MusicRecording', '@id': 'https://horsevision.bandcamp.com/track/how-are-we', 'additionalProperty': [{'@type': 'PropertyValue', 'name': 'track_id', 'value': 2859991095}, {'@type': 'PropertyValue', 'name': 'art_id', 'value': 3703690842}, {'@type': 'PropertyValue', 'name': 'license_name', 'value': 'all_rights_reserved'}, {'@type': 'PropertyValue', 'name': 'tracknum', 'value': 1}], 'name': 'How Are We', 'creditText': 'w/p by Horse Vision\nmixed by Johan Nilsson\nmastered by Jacob Günther Andersen', 'isrcCode': 'QZNWP2551523', 'duration': 'P00H02M40S', 'dateModified': '08 Mar 2025 16:52:55 GMT', 'datePublished': '07 Mar 2025 00:00:00 GMT', 'inAlbum': {'@type': 'MusicAlbum', 'name': 'Another Life', 'albumRelease': [{'@type': 'MusicRelease', '@id': 'https://horsevision.bandcamp.com/album/another-life', 'additionalProperty': [{'@type': 'PropertyValue', 'name': 'item_type', 'value': 'a'}]}, {'@type': ['MusicRelease', 'Product'], '@id': 'https://horsevision.bandcamp.com/track/how-are-we', 'name': 'How Are We', 'additionalProperty': [{'@type': 'PropertyValue', 'name': 'item_id', 'value': 2859991095}, {'@type': 'PropertyValue', 'name': 'item_type', 'value': 't'}, {'@type': 'PropertyValue', 'name': 'selling_band_id', 'value': 1226053264}, {'@type': 'PropertyValue', 'name': 'type_name', 'value': 'Digital'}, {'@type': 'PropertyValue', 'name': 'art_id', 'value': 3703690842}], 'description': 'Includes high-quality download in MP3, FLAC and more. Paying supporters also get unlimited streaming via the free Bandcamp app.', 'offers': {'@type': 'Offer', 'url': 'https://horsevision.bandcamp.com/track/how-are-we#t2859991095-buy', 'priceCurrency': 'SEK', 'price': 15.0, 'priceSpecification': {'minPrice': 15.0}, 'availability': 'OnlineOnly'}, 'musicReleaseFormat': 'DigitalFormat', 'image': ['https://f4.bcbits.com/img/a3703690842_10.jpg']}, {'@type': ['MusicRelease', 'Product'], '@id': 'https://horsevision.bandcamp.com/track/how-are-we#b101211423', 'name': 'full digital discography (11 releases)', 'additionalProperty': [{'@type': 'PropertyValue', 'name': 'item_id', 'value': 101211423}, {'@type': 'PropertyValue', 'name': 'item_type', 'value': 'b'}, {'@type': 'PropertyValue', 'name': 'selling_band_id', 'value': 1226053264}, {'@type': 'PropertyValue', 'name': 'type_name', 'value': 'Digital'}, {'@type': 'PropertyValue', 'name': 'art_id', 'value': 13113720}, {'@type': 'PropertyValue', 'name': 'is_bfd', 'value': True}], 'offers': {'@type': 'Offer', 'url': 'https://horsevision.bandcamp.com/track/how-are-we#b101211423-buy', 'priceCurrency': 'SEK', 'price': 235.2, 'priceSpecification': {'price': 235.2}, 'availability': 'OnlineOnly', 'additionalProperty': [{'@type': 'PropertyValue', 'name': 'bundle_size', 'value': 11}, {'@type': 'PropertyValue', 'name': 'discount', 'value': 0.2}, {'@type': 'PropertyValue', 'name': 'is_set_price', 'value': 1}]}, 'musicReleaseFormat': 'DigitalFormat', 'image': ['https://f4.bcbits.com/img/a0013113720_10.jpg']}], 'albumReleaseType': 'SingleRelease', '@id': 'https://horsevision.bandcamp.com/album/another-life', 'additionalProperty': [{'@type': 'PropertyValue', 'name': 'download_pref', 'value': 2}]}, 'byArtist': {'@type': 'MusicGroup', 'name': 'Horse Vision', '@id': 'https://horsevision.bandcamp.com'}, 'publisher': {'@type': 'MusicGroup', '@id': 'https://horsevision.bandcamp.com', 'name': 'Horse Vision', 'additionalProperty': [{'@type': 'PropertyValue', 'name': 'band_id', 'value': 1226053264}, {'@type': 'PropertyValue', 'name': 'has_any_downloads', 'value': True}, {'@type': 'PropertyValue', 'name': 'has_download_codes', 'value': True}, {'@type': 'PropertyValue', 'name': 'image_height', 'value': 5315}, {'@type': 'PropertyValue', 'name': 'image_id', 'value': 37403428}, {'@type': 'PropertyValue', 'name': 'image_width', 'value': 4252}], 'image': 'https://f4.bcbits.com/img/0037403428_10.jpg', 'genre': 'https://bandcamp.com/discover/alternative', 'description': '☆☆☆☆☆☆☆☆☆\n\nFeel free to contact us regarding anything; will gladly a ...

# %%
#Required fields
fields = (
    'track_type',
    'track_name',
    'artist',
    'album_name',
    'mix_page',
    'record_label',
    'genre',            
    'purchase_link'
)

fields = (
    'streaming_platform',
    'streaming_link'
)

# %%
#Pull out relevant info
def generate_bandcamp_meta_data_dictionary(jsonld_data: json) -> dict:
    '''
    '''
    bandcamp_meta_data_dict = {
        'track_name': jsonld_data.get('name'),
        'artist': jsonld_data.get('byArtist', {}).get('name'),
        'album': jsonld_data.get('inAlbum', {}).get('name'),

    }
    return bandcamp_meta_data_dict

# %%
x = jsonld_data.get('inAlbum', {}).get('name')
x
# Out:
# 'Another Life'

# %% [markdown]
# # YouTube stuff

# %%
url_string = "https://soundcloud.com/wakinglifeportugal/etape"

# %%
def clean_url_string(url_string: str) -> str:
    '''
    
    '''
    split_url_srting = url_string.split(".com")
    clean_url = split_url_srting[0]
    return clean_url

# %%
split_url_srting = url_string.split(".com")
split_url_srting
# Out:
# ['https://soundcloud', '/wakinglifeportugal/etape']

# %%
clean_url = split_url_srting[0]
clean_url
# Out:
# 'https://soundcloud'

# %%
PLATFORM_CHOICES = [
    'youtube',
    'spotify',
    'soundcloud',
    'nina',
    'bandcamp',
    ]

# %% [markdown]
# ## OPTION 1 - SIMPLE

# %%
for choice in PLATFORM_CHOICES:
    if choice in clean_url:
        print("yes")
        break
# Out:
# yes

# %% [markdown]
# ## OPTION 2 - MORE COMPLEX

# %%
any(platform in clean_url for platform in PLATFORM_CHOICES)
# Out:
# True

# %%
es = bool(set(url_string.split(".com")) & set(PLATFORM_CHOICES))
es
# Out:
# False

# %% [markdown]
# ## TESTING YOUTUBE INTEGRATION

# %%
youtube_url =  "https://www.youtube.com/watch?v=zYta6v1wZiI&list=LL&index=1"

# %%
def get_youtube_metadata(video_id: str) -> dict:
    youtube = build("youtube", "v3", developerKey=settings.YOUTUBE_API_KEY)

    response = youtube.videos().list(
        part="snippet",
        id=video_id
    ).execute()

    #Extract snippet from the response
    items = response["items"]
    item=items[0]
    snippet = item["snippet"]

    #Get the title out relevant fields
    title = snippet.get("title")
    #Get the artist from channel title
    channel_title = snippet.get("channelTitle")
    artist = get_artist_from_channel_title(channel_title)
    #Get description
    description = snippet.get("description")

    #Create meta_data_dict
    meta_data_dict = {
        "title": title,
        "artist": artist,
        "description": description,
    }
    return meta_data_dict
